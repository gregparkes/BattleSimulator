# %% [markdown]
# # Notebook 2: A more complicated example
#
# ### Requirements:
#
# - `numpy`
# - `pandas`
# - `matplotlib`
# - `numba`

# %%
import sys
sys.path.insert(0,"../")
# import
import battlesim as bsm

# %% [markdown]
# ### Additional Imports

# %%
from IPython.display import HTML
# %matplotlib inline

# %% [markdown]
# ## A more complex battle

# %%
battle = bsm.Battle("../datasets/starwars-clonewars.csv")

# %% [markdown]
# ## Initialise
#
# 50 Clone troopers versus 100 battledroids.
#
# Except the clones will be in two army groups, and not one.

# %%
armies = [
    bsm.Composite("B1 Battledroid", 80, bsm.Sampling("beta", .5, .5)),
    bsm.Composite("Clone Trooper", 20, bsm.Sampling("normal", 10., 1.)),
    bsm.Composite("Clone Trooper", 30, bsm.Sampling("normal", 7., 1.))
]

# %%
# define 100 battledroids, 50 clones
battle.create_army(armies)
# Out:
# bsm.Battle(init=False)

# %% [markdown]
# ## Run
#
# Here we mostly use random AI selection strategies.

# %%
# run a battle
S1 = battle.simulate()

# %%
battle.sim_jupyter()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgf435ea73dd724739a37bbac3070a9ce2">
#   <div class="anim-controls">
#     <input id="_anim_sliderf435ea73dd724739a37bbac3070a9ce2" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animf435ea73dd724739a37bbac3070a9ce2.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animf435ea73dd724739a37bbac3070a9ce2.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animf435ea73dd724739a37bbac3070a9ce2.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animf435ea73dd724739a37bbac3070a9ce2.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animf435ea73dd724739a37bbac3070a9ce2.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animf435ea73dd724739a37bbac3070a9ce2.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animf435ea73dd724739a37bbac3070a9ce2.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animf435ea73dd724739a37bbac3070a9ce2.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animf435ea73dd724739a37bbac3070a9ce2.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animf435ea73dd724739a37bbac3070a9ce2.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectf435ea73dd724739a37bbac3070a9ce2"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_f435ea73dd724739a37bbac3070a9ce2"
#              >
#       <label for="_anim_radio1_f435ea73dd724739a37bbac3070a9ce2">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_f435ea73dd724739a37bbac3070a9ce2"
#              checked>
#       <label for="_anim_radio2_f435ea73dd724739a37bbac3070a9ce2">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_f435ea73dd724739a37bbac3070a9ce2"
#              >
#       <label for="_anim_radio3_f435ea73dd724739a37bbac3070a9ce2">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf435ea73dd724739a37bbac3070a9ce2";
#     var slider_id = "_anim_sliderf435ea73dd724739a37bbac3070a9ce2";
#     var loop_select_id = "_anim_loop_selectf435ea73dd724739a37bbac3070a9ce2";
#     var frames = new Array(68);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8rg+JYAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %% [markdown]
# ## Saving the animation to file
#
# Rather than generate HTML, we can save the animation as a `.gif` rather easily:
#
# ```python
# battle.sim_export("../simulations/sim1.gif", writer="imagemagick")
# ```

# %% [markdown]
# ## Simulating Multiple Runs at once
#
# Whilst it is nice to see the animation play out in a single run, random effects within the simulation cause variations when you run them multiple times (i.e they are not *deterministic*). What is more interesting to see the average effects across **iterative runs**.
#
# This is achieved using the `simulate_k()` function, also found as a function to our `battle` object. Here we can select `k` as a parameter (anything greater than 1).

# %%
S2 = battle.simulate_k(30)

# %% [markdown]
# ### The output is different... what?
#
# When using `simulate_k()`, the full output from every single `k` run is not returned because the dataset quickly explodes by $n$ and $k$. What is returned instead is, for every Allegiance/Team per $k$, the number of units alive/remaining. This then provides **just the result** of the battle and not the detailed nitty-gritty.

# %%
S2.head()
# Out:
#    Republic  CIS
# 0        39    0
# 1        36    0
# 2        38    0
# 3        37    0
# 4        38    0

# %% [markdown]
# In this case, the Republic win every single iteration. Clearly they have an advantage somehow (humans smarter than droids?).

# %%
S2.gt(0).sum()
# Out:
# Republic    30
# CIS          0
# dtype: int64

# %% [markdown]
# ## Another example, different units
#
# This time, we have 4 army groups, 3 CIS, 1 Republic, with different locations, `nearest` AI options for all, and 1000 iterations.

# %%
armies2 = [
    bsm.Composite("B1 Battledroid", 20, bsm.Sampling("uniform", 2, 2)),
    bsm.Composite("Clone Trooper", 20, bsm.Sampling("normal", 1.5)),
    bsm.Composite("B2 Battledroid", 7, bsm.Sampling("normal", -3., 2.)),
    bsm.Composite("Magmaguard", 4, bsm.Sampling("normal", 4, 2)),
]

# %%
battle2 = bsm.Battle("../datasets/starwars-clonewars.csv")
battle2.create_army(armies2)
# Out:
# bsm.Battle(init=False)

# %%
# run a battle
S3 = battle2.simulate()

# %%
battle2.sim_jupyter()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img687aa62051ec4d8f93fd6d988cace382">
#   <div class="anim-controls">
#     <input id="_anim_slider687aa62051ec4d8f93fd6d988cace382" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim687aa62051ec4d8f93fd6d988cace382.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim687aa62051ec4d8f93fd6d988cace382.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim687aa62051ec4d8f93fd6d988cace382.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim687aa62051ec4d8f93fd6d988cace382.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim687aa62051ec4d8f93fd6d988cace382.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim687aa62051ec4d8f93fd6d988cace382.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim687aa62051ec4d8f93fd6d988cace382.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim687aa62051ec4d8f93fd6d988cace382.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim687aa62051ec4d8f93fd6d988cace382.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim687aa62051ec4d8f93fd6d988cace382.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select687aa62051ec4d8f93fd6d988cace382"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_687aa62051ec4d8f93fd6d988cace382"
#              >
#       <label for="_anim_radio1_687aa62051ec4d8f93fd6d988cace382">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_687aa62051ec4d8f93fd6d988cace382"
#              checked>
#       <label for="_anim_radio2_687aa62051ec4d8f93fd6d988cace382">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_687aa62051ec4d8f93fd6d988cace382"
#              >
#       <label for="_anim_radio3_687aa62051ec4d8f93fd6d988cace382">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img687aa62051ec4d8f93fd6d988cace382";
#     var slider_id = "_anim_slider687aa62051ec4d8f93fd6d988cace382";
#     var loop_select_id = "_anim_loop_select687aa62051ec4d8f93fd6d988cace382";
#     var frames = new Array(28);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8rg+JYAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %%
import numpy as np

# %%
S4 = battle2.simulate_k(100)
S4.gt(0).sum()
# Out:
# Republic      0
# CIS         100
# dtype: int64

# %%
(S4["Republic"] >= S4['CIS']).sum()
# Out:
# 0

# %% [markdown]
# This is the end to the second notebook.
