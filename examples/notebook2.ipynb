# %% [markdown]
# # Notebook 2: A more complicated example
#
# ### Requirements:
#
# - `numpy`
# - `pandas`
# - `matplotlib`
# - `itertools`
# - `scipy.stats`
# - `numba`

# %%
import sys
sys.path.insert(0,"../")
# import
import battlesim as bsm

# %% [markdown]
# ### Additional Imports

# %%
from IPython.display import HTML
# %matplotlib inline

# %% [markdown]
# ## A more complex battle

# %%
battle = bsm.Battle("../datasets/starwars-clonewars.csv")

# %% [markdown]
# ## Initialise
#
# 50 Clone troopers versus 100 battledroids.
#
# Except the clones will be in two army groups, and not one.

# %%
cols = {0:'red',1:'blue'}
labels = {0:'Republic',1:'CIS'}

# %%
# define 100 battledroids, 50 clones
battle.create_army([("B1 battledroid", 80), ("Clone Trooper", 20), ("Clone Trooper", 30)])
# battle droids near (0, 0), clones near (10, 10), default distribution is gaussian
battle.apply_position([bsm.Distribution('beta',a=.5, b=.5,scale=5), bsm.Distribution(loc=10), bsm.Distribution(loc=5).setx(loc=7)])
battle.set_rolling_ai(["random","pack","random"])

# %% [markdown]
# ## Run
#
# Here we mostly use random AI selection strategies.

# %%
# run a battle
S1 = battle.simulate()

# %%
HTML(bsm.quiver_fight(S1,labels,cols).to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img5c3ab345e6244293bff939f1a5770b96">
#     <br>
#     <input id="_anim_slider5c3ab345e6244293bff939f1a5770b96" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim5c3ab345e6244293bff939f1a5770b96.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim5c3ab345e6244293bff939f1a5770b96.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim5c3ab345e6244293bff939f1a5770b96.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim5c3ab345e6244293bff939f1a5770b96.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim5c3ab345e6244293bff939f1a5770b96.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim5c3ab345e6244293bff939f1a5770b96.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim5c3ab345e6244293bff939f1a5770b96.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim5c3ab345e6244293bff939f1a5770b96.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim5c3ab345e6244293bff939f1a5770b96.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim5c3ab345e6244293bff939f1a5770b96.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select5c3ab345e6244293bff939f1a5770b96" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_
# zc/uDBkCLFvmv9Vo0m0KQCIiEjpOnwasVufL5swBFi70X8/NhQvApUuuvxYdDSxaBEybph6gIKcA\
# JCIiocNx+isuDrjvPmDsWP+OwV31Z9gw4N57gXanHkhwUgASEZHQ0NICnDjBjwcPBh56yP9ho7a2\
# 4xRcTAyweDFQVOTbxmvxKgUgEREJDSdPAs3NQGEhcPfdnG7yt337nJe+jxwJ3HMP0K+f/8civaIA\
# JCIioeHECU4xTZ4cmEpLSwuPvACA2Fjg9tsDNxbpNQUgEREJfoYBzJ0LDBwYuDGYS9/z8lj1SUkJ\
# 3Fik1xSAREQk+FksgQ0/hgGUlADLlwMTJ6rq0wcoAImIiHSluZnhJznZu7drGApTAaJNCkRERLoS\
# G+v98AMAe/Zwc0fxOwUgERGRQLh5k+eFnTkT6JGEJQUgERGRQNi2jVNrx44BjY3A

# %% [markdown]
# ## Saving the animation to file
#
# Rather than generate HTML, we can save the animation as a `.gif` rather easily:

# %%
_ = bsm.quiver_fight(S1,labels,cols).save("../simulations/sim1.gif",writer="pillow")

# %% [markdown]
# ## Simulating Multiple Runs at once
#
# Whilst it is nice to see the animation play out in a single run, random effects within the simulation cause variations when you run them multiple times (i.e they are not *deterministic*). What is more interesting to see the average effects across **iterative runs**.
#
# This is achieved using the `simulate_k()` function, also found as a function to our `battle` object. Here we can select `k` as a parameter (anything greater than 1).

# %%
S2 = battle.simulate_k(30)

# %% [markdown]
# ### The output is different... what?
#
# When using `simulate_k()`, the full output from every single `k` run is not returned because the dataset quickly explodes by $n$ and $k$. What is returned instead is, for every Allegiance/Team per $k$, the number of units alive/remaining. This then provides **just the result** of the battle and not the detailed nitty-gritty.

# %%
S2.head()
# Out:
#    Republic  CIS
# 0        49    0
# 1        48    0
# 2        49    0
# 3        49    0
# 4        50    0

# %% [markdown]
# In this case, the Republic win every single iteration. Clearly they have an advantage somehow (humans smarter than droids?).

# %%
S2.gt(0).sum()
# Out:
# Republic    30
# CIS          0
# dtype: int64

# %% [markdown]
# ## Another example, different units
#
# This time, we have 4 army groups, 3 CIS, 1 Republic, with different locations, `nearest` AI options for all, and 1000 iterations.

# %%
battle2 = bsm.Battle("../datasets/starwars-clonewars.csv")
battle2.create_army([("B1 battledroid", 20), ("Clone Trooper", 20),
                    ("B2 battledroid", 7), ("Magmaguard", 4)])
battle2.apply_position([bsm.Distribution("uniform",loc=2,scale=2),bsm.Distribution(scale=1.5),
                       bsm.Distribution(loc=-3,scale=2),bsm.Distribution(loc=4,scale=2).setx(loc=-1)])
battle2.set_initial_ai(["nearest"]*4)
battle2.set_rolling_ai(["nearest"]*4)
# run a battle
S3 = battle2.simulate()

# %%
HTML(bsm.quiver_fight(S3,labels,cols).to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgf6798f9a9cf5484584578d91c5d70a3e">
#     <br>
#     <input id="_anim_sliderf6798f9a9cf5484584578d91c5d70a3e" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animf6798f9a9cf5484584578d91c5d70a3e.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animf6798f9a9cf5484584578d91c5d70a3e.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animf6798f9a9cf5484584578d91c5d70a3e.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animf6798f9a9cf5484584578d91c5d70a3e.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animf6798f9a9cf5484584578d91c5d70a3e.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animf6798f9a9cf5484584578d91c5d70a3e.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animf6798f9a9cf5484584578d91c5d70a3e.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animf6798f9a9cf5484584578d91c5d70a3e.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animf6798f9a9cf5484584578d91c5d70a3e.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animf6798f9a9cf5484584578d91c5d70a3e.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectf6798f9a9cf5484584578d91c5d70a3e" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf6798f9a9cf5484584578d91c5d70a3e";
#     var slider_id = "_anim_sliderf6798f9a9cf5484584578d91c5d70a3e";
#     var loop_select_id = "_anim_loop_selectf6798f9a9cf5484584578d91c5d70a3e";
#     var frames = new Array(55);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4xLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvDW2N/gAAIABJREFUeJzt3Xl01PW9//HXZCMJELawJxBWCfuS\
# CLixyKKIOyqit9al1v7qbW3vbX+3dzn1tLfVWntOtVr7o7f24lKxpVVwR0BEQIQoiwhKWIIkECAQ\
# wpY98/vj7TjZJhsz853J9/k4Z04mM99k3gzRvPh83p/Px+P1er0CAABwkRinCwAAAAg3AhAAAHAd\
# AhAAAHAdAhAAAHAdAhAAAHAdAhAAAHAdAhAAAHAdAhAAAHAdAhAAAHAdAhAAAHAdAhAAAHAdAhAA\
# AHAdAhAAAHCdOKcLuBCpqanKyMhwugwAAOCQvLw8FRUVtfrrojoAZWRkKCcnx+kyAACAQ7Kystr0\
# dUyBAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEA\
# AQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA\
# 1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAQAA1yEAAYgoXq/TFQBwAwIQgIiya5eU\
# l2f3a2qkqipHywHQTsU5XQAA1FZVJT3/vHTjjVJysvTSS9KAAdLgwdKkSVJiotMVAmgPCEAAIkpc\
# nFRdLS1bJvXuLVVWSvv2SQcOSNnZNipUVCTFx0vdujldLYBoRQACEFHiav1f6ehR//34eOnFF6Uj\
# R6TYWOmf/zn8tQFoP+gBAhBR4gL8s6y8XDp4UKqokGbPtukxAGgrAhCAiBIf3/Tz6enShAnhqQVA\
# +0UAAhBRAo0ASVJMjDR/vuTxhK8eAO0TAQhARGkqAE2ebI3RAHChCEAAIkqgAJSSIk2fHtZSALRj\
# BCAAESVQD9BVV0kdOoS3FgDtFwEIQERpbARo2DApMzP8tQBovwhAACJK/QAUFyfNm0fjM4DgIgAB\
# iCj1A9AVV7DjM4DgIwABiCgej+30LEk9ekiXXOJsPQDaJwIQgIjja4S+5pqml8UDQFsRgABEnLg4\
# acwYOwEeAEKBAAQg4nTqJM2d63QVANozAhCAiDNnjoUgAAgVAhCAiMPUF4BQIwABAADXIQABCLuC\
# AqcrAOB2BCAAYff3v0sff2z3166VVq+W9u6VyssdLQuAi7DDBoCwi4+XXntNOnFC2rFDOntW+uAD\
# adw46cYb7ZqKCruOIzAAhAIBCEDYJSTYx40b6z5eUyO99ZZ06JDUpYt0223hrw2AOxCAAIRdhw6N\
# P/7pp/YxNlZasCB89QBwH3qAAISdbwQokEsukbp3D08tQLCcOuV0BWgNAhCAsAs0AiRJKSnS5ZeH\
# rxbgQni99vHMGemFF/yfI/IRgACEXVMjQHPmND9CBOd8/rnTFUSG0lJp3TrpmWds9eLf/iYVFVlD\
# P6IDPUAAwi7QCNDAgdKoUeGtBa3z9tvSuXPSpEm2dUHv3lLnzk5XFV6HD0v/+7+2UlGS/ud/pOPH\
# 7f6JE+57P6IVAQhA2DUWgDwe6eqrWfYeybxeG+F44w0pMdG2MqiokEaMkC67TOrXz+kKQ6e8XKqs\
# tAb9bt3sZ9gXgHzhR7IAlJHhSIlopYgLQNXV1crKylL//v31+uuvO10OgBBobIorO1vq0yf8taDl\
# ysulqiq7/7e/+R/ftUsaPTr0Aai42MKHEyoqpD/9qflG5xMnwlMPLlzE9QA98cQTyszMdLoMACFU\
# fwQoOVmaMcOZWtByTfW37Nhh00K//720bVtoXv/NN6UjR0LzvZvTubN0551SUlLT1xGAokdEBaD8\
# /Hy98cYbuu+++5wuBUAI1R8Bmjmz+V8scF5TAejzz6W8PKlXL9vROxh8o02SVFJi

# %%
S4 = battle2.simulate_k(1000)
S4.gt(0).sum()
# Out:
# Republic    953
# CIS          47
# dtype: int64

# %% [markdown]
# Here we see that the Republic has a 95% win rate compared to the droids, even though they are severely outnumbered.

# %% [markdown]
# This is the end to the second notebook.
